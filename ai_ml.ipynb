# %%
# AEROPREDICT - DATA PREPROCESSING


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("historical_hourly_data_Benowo.csv")

# Display first 5 rows
print("First 5 rows:")
display(df.head())

# Display dataset dimensions
print("\nDataset shape:", df.shape)

# Display column names
print("\nColumn names:")
print(df.columns.tolist())

# Display data types and non-null values
print("\nDataset information:")
df.info()

# Check missing values
print("\nMissing values:")
print(df.isnull().sum())

# Check duplicate rows
print("\nNumber of duplicate rows:", df.duplicated().sum())

# Statistical summary
print("\nStatistical summary:")
display(df.describe())
# Out:
# First 5 rows:
#                  Timezone         Datetime  AQI US  AQI CN  PM2.5 (ug/m3)  \
# 0  Asia/Jakarta UTC+07:00  2/19/2021 13:00      57      21             15
# 1  Asia/Jakarta UTC+07:00  2/19/2021 12:00      50      17             12
# 2  Asia/Jakarta UTC+07:00  2/19/2021 11:00      68      29             20
# 3  Asia/Jakarta UTC+07:00  2/19/2021 10:00     114      58             41
# 4  Asia/Jakarta UTC+07:00   2/19/2021 9:00      88      43             30
#
#    PM10 (ug/m3)  CO2 (ppm)  Temperature (Celsius)  Temperature (Fahrenheit)  \
# 0            57      410.0                   31.0                      87.8
# 1            21      412.0                   31.0                      87.8
# 2            63      411.0                   30.0                      86.0
# 3           139      408.0                   29.0                      84.2
# 4            73      410.0                   28.0                      82.4
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Timezone', 'Datetime', 'AQI US', 'AQI CN', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'CO2 (ppm)', 'Temperature (Celsius)', 'Temperature (Fahrenheit)', 'Humidity (%)', 'Outdoor PM2.5 (ug/m3)', 'HCHO (ppb)', 'TVOC (ppb)']

# %%
# Select the features and target required for AeroPredict

features = [
    'CO2 (ppm)',
    'PM2.5 (ug/m3)',
    'Temperature (Celsius)',
    'Humidity (%)'
]

target = 'AQI US'

# Create dataframe with required columns
data = df[features + [target]].copy()

print("Selected columns:")
display(data.head())

print("\nShape of selected data:", data.shape)
# Out:
# Selected columns:
#    CO2 (ppm)  PM2.5 (ug/m3)  Temperature (Celsius)  Humidity (%)  AQI US
# 0      410.0             15                   31.0          73.0      57
# 1      412.0             12                   31.0          71.0      50
# 2      411.0             20                   30.0          75.0      68
# 3      408.0             41                   29.0          79.0     114
# 4      410.0             30                   28.0          82.0      88
# Shape of selected data: (12831, 5)

# %%
# Check missing values in selected columns

print("Missing values before cleaning:")
print(data.isnull().sum())

# Remove rows containing missing values
data = data.dropna()

print("\nMissing values after cleaning:")
print(data.isnull().sum())

print("\nShape after removing missing values:", data.shape)
# Out:
# Missing values before cleaning:
# CO2 (ppm)                  0
# PM2.5 (ug/m3)              0
# Temperature (Celsius)    125
# Humidity (%)             125
# AQI US                     0
# dtype: int64
#
# Missing values after cleaning:
# CO2 (ppm)                0
# PM2.5 (ug/m3)            0
# Temperature (Celsius)    0
# Humidity (%)             0
# AQI US                   0
# dtype: int64
#
# Shape after removing missing values: (12706, 5)

# %%
# Check and remove duplicate rows

print("Duplicate rows before removal:", data.duplicated().sum())

data = data.drop_duplicates()

print("Duplicate rows after removal:", data.duplicated().sum())

print("\nShape after removing duplicates:", data.shape)
# Out:
# Duplicate rows before removal: 104
# Duplicate rows after removal: 0
#
# Shape after removing duplicates: (12602, 5)

# %%
# Check for physically invalid values

print("Minimum and maximum values:")
display(data.describe().loc[['min', 'max']])

# Remove physically invalid values
data = data[
    (data['CO2 (ppm)'] >= 0) &
    (data['PM2.5 (ug/m3)'] >= 0) &
    (data['Temperature (Celsius)'] >= 0) &
    (data['Humidity (%)'] >= 0) &
    (data['Humidity (%)'] <= 100) &
    (data['AQI US'] >= 0)
]

print("\nShape after validity check:", data.shape)
# Out:
# Minimum and maximum values:
#      CO2 (ppm)  PM2.5 (ug/m3)  Temperature (Celsius)  Humidity (%)  AQI US
# min      390.3            3.0                   20.4          27.5    12.0
# max      953.6          609.0                   40.0          99.0   572.0
# Shape after validity check: (12602, 5)

# %%
print("Final cleaned data:")
display(data.head(10))

print("\nDataset shape:", data.shape)

print("\nData information:")
data.info()
# Out:
# Final cleaned data:
#    CO2 (ppm)  PM2.5 (ug/m3)  Temperature (Celsius)  Humidity (%)  AQI US
# 0      410.0             15                   31.0          73.0      57
# 1      412.0             12                   31.0          71.0      50
# 2      411.0             20                   30.0          75.0      68
# 3      408.0             41                   29.0          79.0     114
# 4      410.0             30                   28.0          82.0      88
# 5      413.0             21                   27.0          86.0      70
# 6      423.0             15                   26.0          89.0      57
# 7      433.0             35                   25.0          92.0      99
# 8      429.0             27                   25.0          91.0      82
# 9      423.0             22                   26.0          90.0      72
# Dataset shape: (12602, 5)
#
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12602 entries, 0 to 12830
# ...

# %%
data.to_csv("AeroPredict_preprocessed.csv", index=False)

print("Preprocessed dataset saved successfully!")
# Out:
# Preprocessed dataset saved successfully!

# %%
import pandas as pd

df = pd.read_csv("historical_hourly_data_Benowo.csv")

print(df.shape)
print(df.columns.tolist())
# Out:
# (12831, 13)
# ['Timezone', 'Datetime', 'AQI US', 'AQI CN', 'PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'CO2 (ppm)', 'Temperature (Celsius)', 'Temperature (Fahrenheit)', 'Humidity (%)', 'Outdoor PM2.5 (ug/m3)', 'HCHO (ppb)', 'TVOC (ppb)']

# %%
import pandas as pd

data = pd.read_csv("AeroPredict_preprocessed.csv")

print("Data loaded successfully!")
print("Shape:", data.shape)
print("Missing values:")
print(data.isnull().sum())
# Out:
# Data loaded successfully!
# Shape: (12602, 5)
# Missing values:
# CO2 (ppm)                0
# PM2.5 (ug/m3)            0
# Temperature (Celsius)    0
# Humidity (%)             0
# AQI US                   0
# dtype: int64

# %%
features = [
    'CO2 (ppm)',
    'PM2.5 (ug/m3)',
    'Temperature (Celsius)',
    'Humidity (%)'
]

target = 'AQI US'

X = data[features]
y = data[target]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (12602, 4)
# y shape: (12602,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training samples:", len(X_train))
print("Validation samples:", len(X_val))
# Out:
# Training samples: 10081
# Validation samples: 2521

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

print("Feature scaling completed successfully!")
# Out:
# Feature scaling completed successfully!

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

lr_model.fit(X_train_scaled, y_train)

print("Linear Regression training completed successfully!")
# Out:
# Linear Regression training completed successfully!

# %%
y_pred_lr = lr_model.predict(X_val_scaled)

print("First 10 predicted AQI values:")
print(y_pred_lr[:10])
# Out:
# First 10 predicted AQI values:
# [ 60.56233861  97.68107479  67.76091444 147.99788598  71.08550264
#  114.29369799  76.8527279   76.7532119   72.77187574 131.22582831]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_lr = mean_absolute_error(y_val, y_pred_lr)
r2_lr = r2_score(y_val, y_pred_lr)

print("Linear Regression Results")
print("-------------------------")
print("MAE:", mae_lr)
print("R² Score:", r2_lr)
# Out:
# Linear Regression Results
# -------------------------
# MAE: 10.377410230642335
# R² Score: 0.8915984887887496

# %%
import joblib

joblib.dump(scaler, "scaler.pkl")

print("Scaler saved successfully as scaler.pkl")
# Out:
# Scaler saved successfully as scaler.pkl
